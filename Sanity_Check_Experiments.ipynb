# %% [markdown]
# 1. Connecting to Google Drive (necessary whenever doing this)

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/My Drive/ELE538B/Final"
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/ELE538B/Final

# %%
# %cd generalization
# Out:
# /content/drive/My Drive/ORF569/Final/Synaptic-Flow-git/Synaptic-Flow

# %%
# !git clone https://github.com/mpsenka21/generalization
# %cd generalization
# after running this, need to move CIFAR-10 folder
# and ideally move it back once done
# or just nvm lol
# Out:
# Cloning into 'generalization'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 129 (delta 3), reused 7 (delta 2), pack-reused 117
# Receiving objects: 100% (129/129), 3.05 MiB | 18.34 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# /content/drive/My Drive/ELE538B/Final/generalization

# %%
# %cd "/content/drive/My Drive/ELE538B/Final"
# !rm -r generalization
# !git clone https://github.com/mpsenka21/generalization
# %cd generalization
# Out:
# /content/drive/My Drive/ELE538B/Final
# Cloning into 'generalization'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 140 (delta 10), reused 16 (delta 6), pack-reused 117
# Receiving objects: 100% (140/140), 3.05 MiB | 18.81 MiB/s, done.
# Resolving deltas: 100% (59/59), done.
# /content/drive/My Drive/ELE538B/Final/generalization

# %%
# !ls
# Out:
#  argparser.py	 models
#  configs	 README.md
#  dataloader.py	'Toy Experiments for Gradient Computation.ipynb'
#  figures	'Toy Experiments for Mini-MNIST.ipynb'
#  functions	 transforms.py
#  LICENSE	 utils.py
#  main.py

# %% [markdown]
# Vanilla training on MNIST

# %%
# !python3 main.py --arch resnet --depth 20 --outdir results --dataset MNIST
# Out:
# [2020/12/12 01:40:23 __main__ INFO] - {
#   "model_config": {
#     "arch": "resnet",
#     "input_shape": [
#       1,
#       1,
#       28,
#       28
#     ],
#     "n_classes": 10,
#     "base_channels": 16,
#     "block_type": "basic",
#     "depth": 20
#   },
#   "optim_config": {
#     "epochs": 160,
#     "batch_size": 128,
#     "optimizer": "sgd",
#     "base_lr": 0.1,
#     "weight_decay": 0.0001,
#     "momentum": 0.9,
#     "nesterov": true,
#     "scheduler": "multistep",
#     "milestones": [
#       80,
#       120
#     ],
#     "lr_decay": 0.1
#   },
#   "data_config": {
#     "dataset": "MNIST",
#     "n_classes": 10,
#     "num_workers": 7,
#     "batch_size": 128,
#     "use_cutout": false,
#     "use_random_erasing": false,
#     "use_mixup": false,
#     "use_gpu": true
#   },
#   "run_config": {
#     "outdir": "results",
#     "seed": 17,
#     "test_first": true,
#     "gpu": "0",
#     "tensorboard": false,
#     "tensorboard_train_images": false,
# ...

# %% [markdown]
# Vanilla training on MiniMNIST

# %%
# !python3 main.py --arch resnet --depth 20 --outdir results --dataset MiniMNIST
# Out:
# [2020/12/12 01:42:42 __main__ INFO] - {
#   "model_config": {
#     "arch": "resnet",
#     "input_shape": [
#       1,
#       1,
#       28,
#       28
#     ],
#     "n_classes": 10,
#     "base_channels": 16,
#     "block_type": "basic",
#     "depth": 20
#   },
#   "optim_config": {
#     "epochs": 160,
#     "batch_size": 128,
#     "optimizer": "sgd",
#     "base_lr": 0.1,
#     "weight_decay": 0.0001,
#     "momentum": 0.9,
#     "nesterov": true,
#     "scheduler": "multistep",
#     "milestones": [
#       80,
#       120
#     ],
#     "lr_decay": 0.1
#   },
#   "data_config": {
#     "dataset": "MiniMNIST",
#     "n_classes": 10,
#     "num_workers": 7,
#     "batch_size": 128,
#     "use_cutout": false,
#     "use_random_erasing": false,
#     "use_mixup": false,
#     "use_gpu": true
#   },
#   "run_config": {
#     "outdir": "results",
#     "seed": 17,
#     "test_first": true,
#     "gpu": "0",
#     "tensorboard": false,
#     "tensorboard_train_images": false,
# ...

# %%
# !python3 main.py --arch resnet --depth 8 --outdir results --dataset MiniMNIST --num_per_class 64
# Out:
# [2020/12/12 02:05:35 __main__ INFO] - {
#   "model_config": {
#     "arch": "resnet",
#     "input_shape": [
#       1,
#       1,
#       28,
#       28
#     ],
#     "n_classes": 10,
#     "base_channels": 16,
#     "block_type": "basic",
#     "depth": 8
#   },
#   "optim_config": {
#     "epochs": 160,
#     "batch_size": 128,
#     "optimizer": "sgd",
#     "base_lr": 0.1,
#     "weight_decay": 0.0001,
#     "momentum": 0.9,
#     "nesterov": true,
#     "scheduler": "multistep",
#     "milestones": [
#       80,
#       120
#     ],
#     "lr_decay": 0.1
#   },
#   "data_config": {
#     "dataset": "MiniMNIST",
#     "num_per_class": 64,
#     "n_classes": 10,
#     "num_workers": 7,
#     "batch_size": 128,
#     "use_cutout": false,
#     "use_random_erasing": false,
#     "use_mixup": false,
#     "use_gpu": true
#   },
#   "run_config": {
#     "outdir": "results",
#     "seed": 17,
#     "test_first": true,
#     "gpu": "0",
#     "tensorboard": false,
# ...

# %% [markdown]
# Mixup on MiniMNIST

# %%
# !python3 main.py --arch resnet --depth 8 --outdir results --dataset MiniMNIST --num_per_class 64 --use_mixup
# Out:
# [2020/12/12 02:07:24 __main__ INFO] - {
#   "model_config": {
#     "arch": "resnet",
#     "input_shape": [
#       1,
#       1,
#       28,
#       28
#     ],
#     "n_classes": 10,
#     "base_channels": 16,
#     "block_type": "basic",
#     "depth": 8
#   },
#   "optim_config": {
#     "epochs": 160,
#     "batch_size": 128,
#     "optimizer": "sgd",
#     "base_lr": 0.1,
#     "weight_decay": 0.0001,
#     "momentum": 0.9,
#     "nesterov": true,
#     "scheduler": "multistep",
#     "milestones": [
#       80,
#       120
#     ],
#     "lr_decay": 0.1
#   },
#   "data_config": {
#     "dataset": "MiniMNIST",
#     "num_per_class": 64,
#     "n_classes": 10,
#     "num_workers": 7,
#     "batch_size": 128,
#     "use_cutout": false,
#     "use_random_erasing": false,
#     "use_mixup": true,
#     "mixup_alpha": 1,
#     "use_gpu": true
#   },
#   "run_config": {
#     "outdir": "results",
#     "seed": 17,
#     "test_first": true,
#     "gpu": "0",
# ...

# %%
# !python3 main.py --arch resnet --depth 8 --outdir results --dataset MiniMNIST --num_per_class 64 --use_mixup --batch_size 64

# %% [markdown]
# Mixup on MNIST

# %%
# !python3 main.py --arch resnet --depth 8 --outdir results --dataset MNIST --use_mixup
# Out:
# [2020/12/12 02:09:43 __main__ INFO] - {
#   "model_config": {
#     "arch": "resnet",
#     "input_shape": [
#       1,
#       1,
#       28,
#       28
#     ],
#     "n_classes": 10,
#     "base_channels": 16,
#     "block_type": "basic",
#     "depth": 8
#   },
#   "optim_config": {
#     "epochs": 160,
#     "batch_size": 128,
#     "optimizer": "sgd",
#     "base_lr": 0.1,
#     "weight_decay": 0.0001,
#     "momentum": 0.9,
#     "nesterov": true,
#     "scheduler": "multistep",
#     "milestones": [
#       80,
#       120
#     ],
#     "lr_decay": 0.1
#   },
#   "data_config": {
#     "dataset": "MNIST",
#     "num_per_class": 128,
#     "n_classes": 10,
#     "num_workers": 7,
#     "batch_size": 128,
#     "use_cutout": false,
#     "use_random_erasing": false,
#     "use_mixup": true,
#     "mixup_alpha": 1,
#     "use_gpu": true
#   },
#   "run_config": {
#     "outdir": "results",
#     "seed": 17,
#     "test_first": true,
#     "gpu": "0",
# ...
